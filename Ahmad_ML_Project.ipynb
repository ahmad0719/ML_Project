# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmad0719/ML_Project/blob/main/Ahmad_ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#%%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import joblib
# Dummy dataset
X = np.random.rand(200,21)
y = np.random.randint(1,4,200)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
report = classification_report(y_test,y_pred,output_dict=True)
import json
json.dump(report, open('classification_report.json','w'))
joblib.dump(model,'best_model.pkl')
# Out:
# ['best_model.pkl']
